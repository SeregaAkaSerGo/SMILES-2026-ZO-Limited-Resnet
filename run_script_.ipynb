# %%
# !python validate.py \
    --data_dir ./data \
    --batch_size 256 \
    --n_batches 32 \
    --seed 42 \
    --output results.json
# Out:
# [Device] Using: cpu
# [Data] Loading CIFAR100 from './data' ...
# ...
# 100%|████████████████████████████████████████| 169M/169M [00:08<00:00, 20.2MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# [Data] Train: 9,600 samples | Val: 10,000 samples
#
# [Checkpoint 1/3] Baseline (ImageNet head)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /home/sergo/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████████████████████████████████| 44.7M/44.7M [00:02<00:00, 19.4MB/s]
#   Top-1: 0.37%
#
# [Checkpoint 2/3] Initialized head (no fine-tuning)
#   Top-1: 1.21%
#
# [Checkpoint 3/3] ZO fine-tuning (32 steps)
#   Active layers: ['fc.weight', 'fc.bias']
#   Fine-tuning: 100%|█████████████| 32/32 [49:29<00:00, 92.81s/step, loss=8.9518]
#   Evaluating fine-tuned model ...
#   Top-1: 1.60%
#
# ...
#  Evaluation Summary
# ...
#   Checkpoint                        Top-1
# ...

# %%
# !python validate.py --data_dir ./data --batch_size 32 --n_batches 16 --seed 42 --output test_results.json
# Out:
# [Device] Using: cpu
# [Data] Loading CIFAR100 from './data' ...
# Files already downloaded and verified
# Files already downloaded and verified
# [Data] Train: 9,600 samples | Val: 10,000 samples
#
# [Checkpoint 1/3] Baseline (ImageNet head)
#   Top-1: 0.37%
#
# [Checkpoint 2/3] Initialized head (no fine-tuning)
#   Top-1: 1.21%
#
# [Checkpoint 3/3] ZO fine-tuning (16 steps)
#   Active layers: ['fc.weight', 'fc.bias']
#   Fine-tuning:   0%|                                   | 0/16 [00:01<?, ?step/s]
# Traceback (most recent call last):
#   File "/home/sergo/Рабочий стол/SMILES/SMILES-2026-ZO-Limited-Resnet/validate.py", line 339, in <module>
#     run_finetuning(
#   File "/home/sergo/Рабочий стол/SMILES/SMILES-2026-ZO-Limited-Resnet/validate.py", line 158, in run_finetuning
#     loss = optimizer.step(loss_fn)
#   File "/home/sergo/miniconda3/envs/reinforcement_learning/lib/python3.10/site-packages/torch/utils/_contextlib.py", line 116, in decorate_context
# ...
